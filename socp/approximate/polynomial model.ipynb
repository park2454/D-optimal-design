# %%
include("functions2.jl")

function f(x)
    return [1, x[1], x[1]^2, x[2], x[2]^2, x[1]*x[2]]
end

ex1 = example(6, [-1,1], f)
# Out:
# example(6, [-1, 1], f)

# %%
misocp(20,6,ex1)
solve!(prob, MosekSolver())
# Out:
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2358
#   Cones                  : 132
#   Scalar variables       : 6745
#   Matrix variables       : 0
#   Integer variables      : 441
#
# Optimizer started.
# Mixed integer optimizer started.
# Threads used: 24
# Presolve started.
# Presolve terminated. Time = 0.15
# Presolved problem: 5566 variables, 726 constraints, 10649 non-zeros
# Presolved problem: 0 general integer, 441 binary, 5125 continuous
# Clique table size: 0
# BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# 0        2        0        0        NA                   NA                   NA          0.7
# Cut generation started.
# Cut generation terminated. Time = 0.07
# 7        17       8        2        NA                   1.0000000000e+300    NA          3.2
# ...
