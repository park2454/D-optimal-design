# %%
include("functions-penalty.jl") # cardinality penalty function with lambda as tuning parameter
# Out:
# misocp (generic function with 1 method)

# %%
function f(x)
    theta = [0.05884, 4.298, 21.8]
    c1 = x*theta[3]*exp(-theta[1]*x)
    c2 = -x*theta[3]*exp(-theta[2]*x) 
    c3 = exp(-theta[2]*x)-exp(-theta[1]*x)
    return [c1; c2; c3]
end

ex1 = example(3,[0,30],f)
#res = misocp(ex1,3000,100,0.5)
# Out:
# example(3, [0, 30], f)

# %%
res = misocp(ex1,300,100,1)
# Out:
# MOSEK warning 705: #224 (nearly) zero elements are specified in sparse row ''(2) of matrix 'A'.
# MOSEK warning 705: #224 (nearly) zero elements are specified in sparse row ''(5) of matrix 'A'.
# MOSEK warning 705: #224 (nearly) zero elements are specified in sparse row ''(8) of matrix 'A'.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 4547
#   Cones                  : 906
#   Scalar variables       : 6045
#   Matrix variables       : 0
#   Integer variables      : 602
#
# Optimizer started.
# Mixed integer optimizer started.
# Threads used: 24
# Presolve started.
# Presolve terminated. Time = 0.20
# Presolved problem: 4225 variables, 2122 constraints, 8596 non-zeros
# Presolved problem: 301 general integer, 301 binary, 3623 continuous
# Clique table size: 0
# BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# ...

# %%
res[1]
# Out:
# 3×2 Array{Float64,2}:
#  34.0   0.2
#  33.0   1.4
#  33.0  18.5

# %%
res = misocp(ex1,600,100,0)
# Out:
# MOSEK warning 705: #448 (nearly) zero elements are specified in sparse row ''(2) of matrix 'A'.
# MOSEK warning 705: #448 (nearly) zero elements are specified in sparse row ''(5) of matrix 'A'.
# MOSEK warning 705: #448 (nearly) zero elements are specified in sparse row ''(8) of matrix 'A'.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7845
#   Cones                  : 1806
#   Scalar variables       : 11444
#   Matrix variables       : 0
#   Integer variables      : 601
#
# Optimizer started.
# Mixed integer optimizer started.
# Threads used: 24
# Presolve started.
# Presolve terminated. Time = 0.06
# Presolved problem: 7824 variables, 3621 constraints, 15946 non-zeros
# Presolved problem: 601 general integer, 0 binary, 7223 continuous
# Clique table size: 0
# BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# ...

# %%
res[1]
# Out:
# 4×2 Array{Float64,2}:
#  33.0   0.25
#  33.0   1.4
#  33.0  18.4
#   1.0  18.45

# %%
res = misocp(ex1,1200,100,0)
# Out:
# MOSEK warning 705: #896 (nearly) zero elements are specified in sparse row ''(2) of matrix 'A'.
# MOSEK warning 705: #896 (nearly) zero elements are specified in sparse row ''(5) of matrix 'A'.
# MOSEK warning 705: #896 (nearly) zero elements are specified in sparse row ''(8) of matrix 'A'.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 15645
#   Cones                  : 3606
#   Scalar variables       : 22844
#   Matrix variables       : 0
#   Integer variables      : 1201
#
# Optimizer started.
# Mixed integer optimizer started.
# Threads used: 24
# Presolve started.
# Presolve terminated. Time = 0.13
# Presolved problem: 15624 variables, 7221 constraints, 31850 non-zeros
# Presolved problem: 1201 general integer, 0 binary, 14423 continuous
# Clique table size: 0
# BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# ...

# %%
res[1]
# Out:
# 13×2 Array{Float64,2}:
#  33.0   0.225
#  27.0   1.375
#   6.0   1.4
#   1.0  18.3
#   1.0  18.325
#   4.0  18.35
#   6.0  18.375
#   8.0  18.4
#   1.0  18.425
#   8.0  18.45
#   3.0  18.475
#   1.0  18.5
#   1.0  18.525

# %%
res = misocp(ex1,3000,100,0)
# Out:
# MOSEK warning 705: #2239 (nearly) zero elements are specified in sparse row ''(2) of matrix 'A'.
# MOSEK warning 705: #2239 (nearly) zero elements are specified in sparse row ''(5) of matrix 'A'.
# MOSEK warning 705: #2239 (nearly) zero elements are specified in sparse row ''(8) of matrix 'A'.
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 39045
#   Cones                  : 9006
#   Scalar variables       : 57044
#   Matrix variables       : 0
#   Integer variables      : 3001
#
# Optimizer started.
# Mixed integer optimizer started.
# Threads used: 24
# Presolve started.
# Presolve terminated. Time = 0.63
# Presolved problem: 39024 variables, 18021 constraints, 79564 non-zeros
# Presolved problem: 3001 general integer, 0 binary, 36023 continuous
# Clique table size: 0
# BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# ...

# %%
res[1]
# Out:
# 10×2 Array{Float64,2}:
#  33.0   0.23
#  33.0   1.39
#   4.0  18.37
#   2.0  18.39
#   6.0  18.4
#   1.0  18.41
#   1.0  18.42
#  15.0  18.43
#   3.0  18.44
#   2.0  18.47

# %%
function f(x)
    theta = [3,-5,0]
    c = exp(theta[1]+theta[2]*(x-theta[3])^2)
    f = [1,(x-theta[3])^2,2*theta[2]*(theta[3]-x) ]
    return sqrt(c)/(1+c)*f
end

ex1 = example(3, [-1,1], f)
#res = misocp(ex1,2000,100,0,0)

# %%
using FileIO, JLD2

@load "penalty.jld2"
# Out:
# 1-element Array{Symbol,1}:
#  :v

# %%
v
# Out:
# 11×2 Array{Any,2}:
#     [33.0 0.2; 33.0 1.4; 28.0 18.4; 6.0 18.5]   11.6684
#     [34.0 0.2; 33.0 1.4; 33.0 18.5]             11.6686
#     [33.0 0.2; 33.0 1.4; 34.0 18.4]             11.6686
#     [33.0 0.2; 34.0 1.4; 33.0 18.4]             11.6686
#     [100.0 11.4]                                 0.00372244
#  #undef                                        #undef
#  #undef                                        #undef
#  #undef                                        #undef
#  #undef                                        #undef
#  #undef                                        #undef
#  #undef                                        #undef
